# %%
### 최근 5년 지하철 사고발생건수

# %%
import pandas as pd

df = pd.read_csv("C:/Users/82102/OneDrive/바탕 화면/경희대학교/동아리/쿠다/ML_session/toy_project/raw_data/서울교통공사_최근 5년 지하철 사고 현황_20231231.csv")

# %%
df=df.groupby('발생역').count().reset_index()

df
# Out:
#             발생역  발생일자
# 0   가산디지털단지(7)역    11
# 1         강남구청역     4
# 2      건대입구(2)역    12
# 3      건대입구(7)역    12
# 4     고속터미널(3)역    19
# 5     고속터미널(7)역    24
# 6           공릉역     5
# 7        광명사거리역     6
# 8            군자     1
# 9        군자(5)역    18
# 10       군자(7)역    10
# 11          군자역     2
# 12         남구로역     3
# 13          남성역     1
# 14          내방역     1
# 15       노원(4)역    15
# 16       노원(7)역     8
# 17          논현역     6
# 18       대림(2)역     7
# 19       대림(7)역    16
# 20      도봉산(7)역    17
# 21       뚝섬유원지역     1
# 22          마들역     7
# 23          먹골역     7
# 24          면목역     7
# 25          반포역     1
# 26         보라매역     4
# 27        부천시청역     1
# 28     부평구청(7)역     2
# 29        부평구청역     2
# 30         사가정역     7
# 31       삼산체육관역     1
# 32          상도역     7
# 33          상동역     6
# 34       상봉(7)역     2
# 35          상봉역     5
# 36         수락산역    11
# 37       숭실대입구역     4
# 38      신대방삼거리역     7
# 39          신풍역     3
# ...

# %%
df.loc[0, '발생역']='가산디지털단지역'
df.loc[2, '발생역']='건대입구역'
df.loc[3, '발생역']='건대입구역'
df.loc[4, '발생역']='고속터미널역'
df.loc[5, '발생역']='고속터미널역'
df.loc[8, '발생역']='군자역'
df.loc[9, '발생역']='군자역'
df.loc[10, '발생역']='군자역'
df.loc[15, '발생역']='노원역'
df.loc[16, '발생역']='노원역'
df.loc[18, '발생역']='대림역'
df.loc[19, '발생역']='대림역'
df.loc[20, '발생역']='도봉산역'
df.loc[28, '발생역']='부평구청역'
df.loc[34, '발생역']='상봉역'
df.loc[41, '발생역']='온수역'
df.loc[44, '발생역']='이수역'
df.loc[45, '발생역']='이수역'
df.loc[55, '발생역']='태릉입구역'
df.loc[56, '발생역']='태릉입구역'

df
# Out:
#          발생역  발생일자
# 0   가산디지털단지역    11
# 1      강남구청역     4
# 2      건대입구역    12
# 3      건대입구역    12
# 4     고속터미널역    19
# 5     고속터미널역    24
# 6        공릉역     5
# 7     광명사거리역     6
# 8        군자역     1
# 9        군자역    18
# 10       군자역    10
# 11       군자역     2
# 12      남구로역     3
# 13       남성역     1
# 14       내방역     1
# 15       노원역    15
# 16       노원역     8
# 17       논현역     6
# 18       대림역     7
# 19       대림역    16
# 20      도봉산역    17
# 21    뚝섬유원지역     1
# 22       마들역     7
# 23       먹골역     7
# 24       면목역     7
# 25       반포역     1
# 26      보라매역     4
# 27     부천시청역     1
# 28     부평구청역     2
# 29     부평구청역     2
# 30      사가정역     7
# 31    삼산체육관역     1
# 32       상도역     7
# 33       상동역     6
# 34       상봉역     2
# 35       상봉역     5
# 36      수락산역    11
# 37    숭실대입구역     4
# 38   신대방삼거리역     7
# 39       신풍역     3
# 40   어린이대공원역    11
# 41       온수역     6
# 42       온수역     1
# 43      용마산역     1
# 44       이수역    15
# 45       이수역    13
# ...

# %%
df=df.groupby('발생역').sum().reset_index()

df
# Out:
#          발생역  발생일자
# 0   가산디지털단지역    11
# 1      강남구청역     4
# 2      건대입구역    24
# 3     고속터미널역    43
# 4        공릉역     5
# 5     광명사거리역     6
# 6        군자역    31
# 7       남구로역     3
# 8        남성역     1
# 9        내방역     1
# 10       노원역    23
# 11       논현역     6
# 12       대림역    23
# 13      도봉산역    17
# 14    뚝섬유원지역     1
# 15       마들역     7
# 16       먹골역     7
# 17       면목역     7
# 18       반포역     1
# 19      보라매역     4
# 20     부천시청역     1
# 21     부평구청역     4
# 22      사가정역     7
# 23    삼산체육관역     1
# 24       상도역     7
# 25       상동역     6
# 26       상봉역     7
# 27      수락산역    11
# 28    숭실대입구역     4
# 29   신대방삼거리역     7
# 30       신풍역     3
# 31   어린이대공원역    11
# 32       온수역     7
# 33      용마산역     1
# 34       이수역    28
# 35     장승배기역     5
# 36       장암역     1
# 37       중계역     4
# 38       중곡역     5
# 39       중화역     4
# 40       천왕역     5
# 41       철산역    21
# 42       청담역     6
# 43       춘의역     1
# 44     태릉입구역     7
# 45       하계역     7
# ...

# %%
df.to_csv('사고.csv', index=False, encoding='utf-8-sig')
